# %%
import pandas as pd

# %%
import openpyxl

# %%
i = 2008
boy_babyname = pd.DataFrame()
girl_babyname = pd.DataFrame()
boy = []
gitl = []
while True:
    try:
        boy_filename = "상위 출생신고 이름 현황_" + str(i) + "남.xls"
        girl_filename = "상위 출생신고 이름 현황_" + str(i) + "여.xls"
        nme = str(i)+"년 이름"
        boy = pd.read_excel("C:\\Users\\Admin\\Desktop\\name\\babyname\\" + boy_filename, header = 1, names = ['순위', nme, '전체비율', '건수'])
        girl = pd.read_excel("C:\\Users\\Admin\\Desktop\\name\\babyname\\" + girl_filename, header = 1, names = ['순위', nme, '전체비율', '건수'])
        print(i,"년 가져옴")
        boy_babyname = pd.concat([boy_babyname, boy],axis = 1)
        girl_babyname = pd.concat([girl_babyname,girl],axis = 1)
        i = i + 1
        print(i,"년 합침")
    except:
        print(i, "년 가져오다가 으악")
        break
# Out:
# 2008 년 가져옴
# 2009 년 합침
# 2009 년 가져옴
# 2010 년 합침
# 2010 년 가져옴
# 2011 년 합침
# 2011 년 가져옴
# 2012 년 합침
# 2012 년 가져옴
# 2013 년 합침
# 2013 년 가져옴
# 2014 년 합침
# 2014 년 가져옴
# 2015 년 합침
# 2015 년 가져옴
# 2016 년 합침
# 2016 년 가져옴
# 2017 년 합침
# 2017 년 가져옴
# 2018 년 합침
# 2018 년 가져옴
# 2019 년 합침
# 2019 년 가져옴
# 2020 년 합침
# 2020 년 가져옴
# 2021 년 합침
# 2021 년 가져옴
# 2022 년 합침
# 2022 년 가져옴
# 2023 년 합침
# 2023 년 가져오다가 으악

# %%
girl_babyname = girl_babyname.drop(['순위'], axis = 1)

# %%
boy_babyname = boy_babyname.drop(['순위'], axis = 1)

# %%
girl_babyname
# Out:
#    2008년 이름        전체비율      건수 2009년 이름        전체비율      건수 2010년 이름  \
# 0        서연   서연(7.69%)    3316       서연   서연(8.25%)    3553       서연
# 1        민서   민서(6.71%)    2892       민서   민서(7.02%)    3023       서현
# 2        지민   지민(6.60%)    2844       서현   서현(6.32%)    2723       민서
# 3        서현   서현(6.13%)    2645       지우   지우(5.93%)    2555       지우
# 4        서윤   서윤(5.81%)    2505       서윤   서윤(5.82%)    2506       서윤
# 5        예은   예은(5.49%)    2369       지민   지민(5.79%)    2494       지민
# 6        하은   하은(4.95%)    2135       수빈   수빈(5.20%)    2240       하은
# 7        지우   지우(4.94%)    2128       하은   하은(5.20%)    2239       윤서
# 8        수빈   수빈(4.88%)    2103       예은   예은(4.86%)    2093       수빈
# 9        윤서   윤서(4.67%)    2014       윤서   윤서(4.54%)    1957       지윤
# 10       유진   유진(4.56%)    1967       민지   민지(4.35%)    1875       은서
# 11       은서   은서(4.50%)    1940       지윤   지윤(4.31%)    1856       예은
# ...

# %%
boy_babyname
# Out:
#    2008년 이름        전체비율      건수 2009년 이름        전체비율      건수 2010년 이름  \
# 0        민준   민준(8.21%)    2656       민준   민준(9.27%)    3130       민준
# 1        지훈   지훈(6.77%)    2191       지후   지후(6.43%)    2170       지훈
# 2        현우   현우(6.02%)    1947       지훈   지훈(5.95%)    2007       예준
# 3        준서   준서(5.89%)    1905       현우   현우(5.75%)    1940       현우
# 4        우진   우진(5.65%)    1827       준서   준서(5.67%)    1913       준서
# 5        건우   건우(5.31%)    1720       건우   건우(5.35%)    1805       지호
# 6        예준   예준(5.29%)    1713       예준   예준(5.33%)    1798       현준
# 7        현준   현준(5.03%)    1627       현준   현준(5.06%)    1707       건우
# 8        도현   도현(4.94%)    1599       우진   우진(4.65%)    1568       서준
# 9        준혁   준혁(4.93%)    1595       민재   민재(4.57%)    1544       지후
# 10       동현   동현(4.87%)    1577       시우   시우(4.57%)    1542       준혁
# 11       민재   민재(4.59%)    1484       민성   민성(4.45%)    1503       시우
# ...
